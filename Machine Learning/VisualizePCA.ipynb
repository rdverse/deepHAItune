# %%
from DataBuilder import DataBuilder
import numpy as np

# %%
X = MLData.dataset_main(150,50, Accel = True, Resultant)
# Out:
#   File "<ipython-input-2-538c94a15e28>", line 1
#     X = MLData.dataset_main(150,50, Accel = True, Resultant)
#                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
dataBuilder = DataBuilder(False, False)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# building data
# Accel
# 29
# Train Labels shape   : (3613, 1)
# Train Features shape : (3613, 150)
# Test labels shape    : (1549, 1)
# Test Features shape  : (1549, 150)
# Gyro
# 29
# Train Labels shape   : (3613, 1)
# Train Features shape : (3613, 150)
# Test labels shape    : (1549, 1)
# Test Features shape  : (1549, 150)
# Accel
# 29
# Train Labels shape   : (3613, 1)
# Train Features shape : (3613, 50)
# Test labels shape    : (1549, 1)
# Test Features shape  : (1549, 50)
# Gyro
# 29
#  33%|███▎      | 1/3 [00:08<00:17,  8.66s/it]
# Train Labels shape   : (3613, 1)
# Train Features shape : (3613, 50)
# Test labels shape    : (1549, 1)
# Test Features shape  : (1549, 50)
# (3613, 150)
# Accel
# 14
# Train Labels shape   : (1744, 1)
# Train Features shape : (1744, 300)
# Test labels shape    : (748, 1)
# Test Features shape  : (748, 300)
# Gyro
# 14
# Train Labels shape   : (1744, 1)
# Train Features shape : (1744, 300)
# ...

# %%
X_Train, y_Train, X_Test,  y_Test = dataBuilder.confs['data1']['conf1']
X_TrainG, y_TrainG, X_TestG,  y_TestG = dataBuilder.confs['data1']['conf1']

# %%
a,b,c = np.split(X_Train[3], 3)
#plt.plot(np.square(a)- np.mean(np.square(a)), color = 'black')
#plt.twinx()
plt.plot(a, color = 'blue')
plt.plot(b, color = 'red')
plt.plot(c, color='green')

#plt.plot(np.square(b), color = 'red')
#plt.plot(np.square(c), color='green')
plt.show()
y_Train[3]
# Out:
# array([4.5])

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X_Train, y_Train)
# Out:
# PCA(n_components=2)

# %%
preds = pca.transform(X_Test)

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture

GM = GaussianMixture(n_components=2,)
GM.fit(X_Train)
p = GM.fit_predict(preds)

kmeans = KMeans(n_clusters=2)
kmeans.fit(X_Train)
km = kmeans.predict(X_Test)
preds=preds/1000
spec = SpectralClustering(n_clusters=2,affinity='rbf', gamma = 1.2)
sc = spec.fit_predict(preds)

#db = DBSCAN(n_clusters = 2,eps=10, min_samples = 2)

#db.fit(X_Train)

#dbpreds = db.fit_predict(preds)

# %%
pree = y_Test

# %%
import matplotlib.pyplot as plt
plt.style.use('default')
plt.scatter(preds[:,0],preds[:,1],c=y_Test)
plt.colorbar()
plt.show()
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('default')
plt.scatter(preds[:,0],preds[:,1],c=y_Test)
plt.colorbar()
plt.show()
# %matplotlib inline

# %%
preds[:,1].shape
# Out:
# (481,)

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.1'

# %%
# Out:
# (1121,)
