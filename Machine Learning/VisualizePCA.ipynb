# %%
from DataBuilder import DataBuilder
import numpy as np

# %%
X = MLData.dataset_main(150,50, Accel = True, Resultant)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e5c995327bb7> in <module>
# ----> 1 X_Train, X_Test, y_Train, y_Test = MLData.dataset_main(150,50)
#
# TypeError: dataset_main() missing 2 required positional arguments: 'Accel' and 'Resultant'

# %%
dataBuilder = DataBuilder(False)
# Out:
# 100%|██████████| 3/3 [01:51<00:00, 37.01s/it]

# %%
X_Train, y_Train, X_Test,  y_Test = dataBuilder.confs['data3']['conf5']

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X_Train, y_Train)
# Out:
# PCA(n_components=2)

# %%
preds = pca.transform(X_Test)

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture

GM = GaussianMixture(n_components=2,)
GM.fit(X_Train)
p = GM.fit_predict(preds)

kmeans = KMeans(n_clusters=2)
kmeans.fit(X_Train)
km = kmeans.predict(X_Test)
preds=preds/1000
spec = SpectralClustering(n_clusters=2,affinity='rbf', gamma = 1.2)
sc = spec.fit_predict(preds)

#db = DBSCAN(n_clusters = 2,eps=10, min_samples = 2)

#db.fit(X_Train)

#dbpreds = db.fit_predict(preds)

# %%
pree = y_Test

# %%
import matplotlib.pyplot as plt
plt.style.use('default')
plt.scatter(preds[:,0],preds[:,1],c=y_Test)
plt.colorbar()
plt.show()
# %matplotlib inline

# %%
dataBuilder.confs['data3']['conf5'][0].shape
# Out:
# (1121, 900)

# %%
preds[:,1].shape
# Out:
# (481,)

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.1'

# %%
sc.shape
# Out:
# (1121,)
